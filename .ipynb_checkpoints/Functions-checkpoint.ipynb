# %% [markdown]
# #### Regressions

# %%
from sklearn.linear_model import LinearRegression

inputs=non_smoker_df[['age']]
targets=non_smoker_df.charges
model=LinearRegression().fit(inputs,targets)

# %% [markdown]
# #### Metrics

# %%
from sklearn.metrics import root_mean_squared_error

loss=root_mean_squared_error(targets,predictions)

# %% [markdown]
# #### Preprocessing

# %%
from sklearn import preprocessing

enc.preprocessing.OneHotEncoder()
enc.fit(medical_df[['region']])
one_hot=enc.transform(medical_df[['region']]).toarray()
medical_df[['northeast','nortwest','southeast','southwest']]=one_hot
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 from sklearn import preprocessing
# ----> 3 enc.preprocessing.OneHotEncoder()
#       4 enc.fit(medical_df[['region']])
#       5 one_hot=enc.transform(medical_df[['region']]).toarray()
#
# NameError: name 'enc' is not defined

# %% [markdown]
# #### Model Selection

# %%
from sklearn.model_selection import train_test_split

inputs_train, inputs_test, targets_train, targets_test=train_test_split(inputs, targets, test_size=0.1)
model=LinearRegression().fit(inputs_train, targets_train)
test_loss=rmse(inputs_test, predicictions_test)
train_loss=rmse(targets_train, predictions_train)
